# %%
# !rm -rf ECG
# !git clone -b new_features https://github.com/YouCanKeepSilence/ECG.git
# !pip3 install -q -r ECG/requirements.txt
# Out:
# Cloning into 'ECG'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 127 (delta 3), reused 8 (delta 2), pack-reused 116
# Receiving objects: 100% (127/127), 231.11 MiB | 14.18 MiB/s, done.
# Resolving deltas: 100% (63/63), done.
# Checking out files: 100% (11/11), done.
#      |████████████████████████████████| 163kB 25.3MB/s
#      |████████████████████████████████| 808kB 19.3MB/s
#      |████████████████████████████████| 163kB 53.6MB/s
#      |████████████████████████████████| 92kB 12.7MB/s
#      |████████████████████████████████| 2.9MB 51.6MB/s
#      |████████████████████████████████| 296kB 49.6MB/s
#      |████████████████████████████████| 51kB 7.7MB/s
#      |████████████████████████████████| 92kB 13.1MB/s
#      |████████████████████████████████| 20.2MB 1.3MB/s
#      |████████████████████████████████| 2.1MB 44.8MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Et6O5ihcFuPDXgnkTnUvuwTao0Pmayvq' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1Et6O5ihcFuPDXgnkTnUvuwTao0Pmayvq" -O data.zip && rm -rf /tmp/cookies.txt
# Out:
# --2020-05-22 23:30:00--  https://docs.google.com/uc?export=download&confirm=6zd_&id=1Et6O5ihcFuPDXgnkTnUvuwTao0Pmayvq
# Resolving docs.google.com (docs.google.com)... 172.217.194.138, 172.217.194.113, 172.217.194.139, ...
# Connecting to docs.google.com (docs.google.com)|172.217.194.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-3s-docs.googleusercontent.com/docs/securesc/v2jk9gq37jk26lsodq1d5d3m6ggrbbc7/rhvekkvhbfp2b8t9cuuvrq8j0bseo07a/1590190200000/13424882956305752741/10995457202133949735Z/1Et6O5ihcFuPDXgnkTnUvuwTao0Pmayvq?e=download [following]
# --2020-05-22 23:30:00--  https://doc-0k-3s-docs.googleusercontent.com/docs/securesc/v2jk9gq37jk26lsodq1d5d3m6ggrbbc7/rhvekkvhbfp2b8t9cuuvrq8j0bseo07a/1590190200000/13424882956305752741/10995457202133949735Z/1Et6O5ihcFuPDXgnkTnUvuwTao0Pmayvq?e=download
# ...

# %%
# !unzip -o -q '/content/data.zip'

# %%
import sys
sys.path.append('/content')
sys.path.append('/content/ECG')

# %%
# args = {
#     'lr': 0.001,
#     'epochs': 20,
#     'batch': 2000,
#     'slice': 2500,
#     'multiplier': 40,
#     'print_every': 1,
#     'num_classes': 9,
#     'type': 'VGG_11',
#     'base_path': '/content/drive/driveMy Drive/ML/TrainingSet1' 
# }

class Args:
  lr = 0.001
  epochs = 20
  batch = 500
  slice = 2500
  multiplier = 1
  print_every = 1
  num_classes = 9
  type = 'VGG_11'
  # base_path = '/content/drive/My Drive/ML/TrainingSet1' 
  base_path = '/content/TrainingSet1'

# %%
from ECG import train
# Out:
# /usr/local/lib/python3.6/dist-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# Using TensorFlow backend.

# %%
train.train(Args)
# Out:
# 2020-05-22 23:54:25.294406 Loading data
# 2020-05-22 23:56:26.779517 Create loaders
# 2020-05-22 23:56:44.571226 Train started
# 2020-05-22 23:56:46.888761
#  Epoch: 0, Iteration: 0
# Loss: 2.205575704574585 , Acc: 0.122
# Val Loss: 2.0253482659657798, Val Acc: 0.31625157232704404
#
# 2020-05-22 23:56:48.683773
#  Epoch: 0, Iteration: 1
# Loss: 6.385989189147949 , Acc: 0.324
# Val Loss: 2.2058085600535073, Val Acc: 0.18747169811320755
#
# 2020-05-22 23:56:50.492015
#  Epoch: 0, Iteration: 2
# Loss: 6.292606830596924 , Acc: 0.174
# Val Loss: 2.1598170598347983, Val Acc: 0.14831446540880502
#
# 2020-05-22 23:56:52.289290
#  Epoch: 0, Iteration: 3
# Loss: 4.88415002822876 , Acc: 0.222
# Val Loss: 2.396991411844889, Val Acc: 0.13564779874213836
#
# 2020-05-22 23:56:54.007015
#  Epoch: 0, Iteration: 4
# Loss: 3.6649656295776367 , Acc: 0.1600877192982456
# Val Loss: 2.2907931804656982, Val Acc: 0.06695597484276729
#
# Checkpoint of epoch 0 saved-----------------------------------------
#
# ...
